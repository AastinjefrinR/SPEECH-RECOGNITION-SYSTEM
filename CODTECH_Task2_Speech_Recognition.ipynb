# %%
# !pip install SpeechRecognition pydub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 24.4 MB/s eta 0:00:00

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c758c474-455b-4cde-ad00-75468c7fb3b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c758c474-455b-4cde-ad00-75468c7fb3b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import speech_recognition as sr

recognizer = sr.Recognizer()

audio_file = "wav.aac"  # change this to match your uploaded filename exactly

with sr.AudioFile(audio_file) as source:
    print("Listening to audio...")
    audio_data = recognizer.record(source)
    print("Converting speech to text...")
    text = recognizer.recognize_google(audio_data)

print("\n===== TRANSCRIBED TEXT =====\n")
print(text)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/speech_recognition/__init__.py in __enter__(self)
#     234             # attempt to read the file as WAV
# --> 235             self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#     236             self.little_endian = True  # RIFF WAV is a little-endian format (most ``audioop`` operations assume that the frames are stored in little-endian form)
#
# /usr/lib/python3.12/wave.py in open(f, mode)
#     648     if mode in ('r', 'rb'):
# --> 649         return Wave_read(f)
#     650     elif mode in ('w', 'wb'):
#
# /usr/lib/python3.12/wave.py in __init__(self, f)
#     285         try:
# --> 286             self.initfp(f)
#     287         except:
#
# /usr/lib/python3.12/wave.py in initfp(self, file)
#     252         if self._file.getname() != b'RIFF':
# ...

# %%
print(uploaded.keys())
# Out:
# dict_keys(['wav.aac'])

# %%
# !apt-get install -y ffmpeg -q
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.

# %%
from pydub import AudioSegment
import speech_recognition as sr

# Your uploaded file
input_file = "wav.aac"

# Convert AAC to proper PCM WAV
sound = AudioSegment.from_file(input_file, format="aac")
sound = sound.set_channels(1)
sound.export("converted.wav", format="wav")

print("Conversion done!")

# Speech recognition on converted file
recognizer = sr.Recognizer()

with sr.AudioFile("converted.wav") as source:
    print("Listening to audio...")
    audio_data = recognizer.record(source)
    print("Converting speech to text...")
    text = recognizer.recognize_google(audio_data)

print("\n===== TRANSCRIBED TEXT =====\n")
print(text)
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Conversion done!
# Listening to audio...
# Converting speech to text...
#
# ===== TRANSCRIBED TEXT =====
#
# hi hello my name is Austin Jeffrey you are okay 24021
